# %%
# imports

from pathlib import Path
import json
import re
import time

import pandas as pd

# colab data folder
DATA_DIR = Path("/content")

# input paths
CASES_FILE = DATA_DIR / "in_scope_QA.csv"
GUIDELINES_FILE = DATA_DIR / "QA_guidelines.csv"
OUT_OF_SCOPE_CASES_FILE = DATA_DIR / "out_of_scope_QA.csv"

# %%
# load and validate data

# input files
library_cases_df = pd.read_csv(CASES_FILE)
guidelines_df = pd.read_csv(GUIDELINES_FILE)
out_of_scope_cases_df = pd.read_csv(OUT_OF_SCOPE_CASES_FILE)

# expected case schema
required_case_columns = [
    "case_id",
    "question_en",
    "question_nl",
    "context",
    "reference_answer_en",
    "reference_answer_nl",
    "expected_answer_points",
    "should_not_include",
]

# expected guideline schema
required_guideline_columns = [
    "guideline_type",
    "guideline_text",
]


def validate_case_dataframe(df: pd.DataFrame, dataframe_name: str) -> None:
    """
    Check whether a case dataframe contains all required columns.
    """

    # schema check
    missing_columns = [col for col in required_case_columns if col not in df.columns]

    if missing_columns:
        raise ValueError(f"{dataframe_name} is missing required columns: {missing_columns}")


def clean_case_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """
    Clean text fields in a case dataframe.
    """

    cleaned_df = df.copy()

    # text cleanup
    for col in required_case_columns:
        cleaned_df[col] = cleaned_df[col].fillna("").astype(str).str.strip()

    return cleaned_df


def validate_guidelines_dataframe(df: pd.DataFrame) -> None:
    """
    Check whether the guidelines dataframe contains all required columns.
    """

    missing_columns = [col for col in required_guideline_columns if col not in df.columns]

    if missing_columns:
        raise ValueError(f"Guidelines dataframe is missing required columns: {missing_columns}")


def clean_guidelines_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """
    Clean text fields in the guidelines dataframe.
    """

    cleaned_df = df.copy()

    # text cleanup
    cleaned_df["guideline_type"] = cleaned_df["guideline_type"].fillna("").astype(str).str.strip()
    cleaned_df["guideline_text"] = cleaned_df["guideline_text"].fillna("").astype(str).str.strip()

    return cleaned_df


# run checks
validate_case_dataframe(library_cases_df, "library_cases_df")
validate_case_dataframe(out_of_scope_cases_df, "out_of_scope_cases_df")
validate_guidelines_dataframe(guidelines_df)

# apply cleanup
library_cases_df = clean_case_dataframe(library_cases_df)
out_of_scope_cases_df = clean_case_dataframe(out_of_scope_cases_df)
guidelines_df = clean_guidelines_dataframe(guidelines_df)

print("All files validated and cleaned.")
# Out:
# Library cases shape: (50, 9)
# Guidelines shape: (63, 2)
# Out-of-scope cases shape: (30, 9)
# All files validated and cleaned.

# %%
def expand_cases_to_items(
    cases_df: pd.DataFrame,
    dataset_name: str,
) -> pd.DataFrame:
    """
    Expand each bilingual case into separate English and Dutch items.
    """

    benchmark_items = []
    case_records = cases_df.to_dict(orient="records")

    # one row per language
    for case in case_records:
        base_case_id = case["case_id"]
        context = case["context"]
        expected_answer_points = case["expected_answer_points"]
        should_not_include = case["should_not_include"]

        # english item
        if case["question_en"]:
            benchmark_items.append({
                "item_id": f"{base_case_id}_EN",
                "base_case_id": base_case_id,
                "dataset": dataset_name,
                "language": "en",
                "question": case["question_en"],
                "context": context,
                "reference_answer": case["reference_answer_en"],
                "expected_answer_points": expected_answer_points,
                "should_not_include": should_not_include,
            })

        # dutch item
        if case["question_nl"]:
            benchmark_items.append({
                "item_id": f"{base_case_id}_NL",
                "base_case_id": base_case_id,
                "dataset": dataset_name,
                "language": "nl",
                "question": case["question_nl"],
                "context": context,
                "reference_answer": case["reference_answer_nl"],
                "expected_answer_points": expected_answer_points,
                "should_not_include": should_not_include,
            })

    return pd.DataFrame(benchmark_items)


# in-scope items
in_scope_test_df = expand_cases_to_items(
    cases_df=library_cases_df,
    dataset_name="in_scope",
)

# out-of-scope items
out_of_scope_test_df = expand_cases_to_items(
    cases_df=out_of_scope_cases_df,
    dataset_name="out_of_scope",
)

# routing benchmark
test_df = pd.concat(
    [in_scope_test_df, out_of_scope_test_df],
    ignore_index=True,
)

print("Case library shape:", in_scope_test_df.shape)
print("Out-of-scope test shape:", out_of_scope_test_df.shape)
print("Combined routing test shape:", test_df.shape)

display(test_df[["item_id", "dataset", "language", "question"]].head(10))
# Out:
# Case library shape: (100, 9)
# Out-of-scope test shape: (60, 9)
# Combined routing test shape: (160, 9)
#            item_id   dataset language  \
# 0  EXISTING_001_EN  in_scope       en
# 1  EXISTING_001_NL  in_scope       nl
# 2  EXISTING_002_EN  in_scope       en
# 3  EXISTING_002_NL  in_scope       nl
# 4  EXISTING_003_EN  in_scope       en
# 5  EXISTING_003_NL  in_scope       nl
# 6  EXISTING_004_EN  in_scope       en
# 7  EXISTING_004_NL  in_scope       nl
# 8  EXISTING_005_EN  in_scope       en
# 9  EXISTING_005_NL  in_scope       nl
#
#                                             question
# 0  Why is my electricity use suddenly higher at n...
# 1  Waarom is mijn elektriciteitsverbruik 's nacht...
# 2  Why is my electricity usage higher this month ...
# 3  Waarom is mijn elektriciteitsverbruik deze maa...
# 4  Why does my energy pattern look different in w...
# 5  Waarom ziet mijn energiepatroon er in de winte...
# 6  Why does my heat pump use energy even when I h...
# 7  Waarom verbruikt mijn warmtepomp energie ook a...
# 8  Why does my balanced ventilation system seem t...
# 9  Waarom lijkt mijn gebalanceerde ventilatiesyst...

# %%
# lingua setup

# %pip install -q "lingua-language-detector"

from lingua import Language, LanguageDetectorBuilder

# current benchmark languages
lingua_detector = (
    LanguageDetectorBuilder
    .from_languages(Language.ENGLISH, Language.DUTCH)
    .build()
)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 6.8 MB/s eta 0:00:00

# %%
# model setup

# %pip install -q -U "transformers>=4.38.0" "accelerate" "bitsandbytes>=0.46.1" "sentencepiece"

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

from google.colab import userdata
from huggingface_hub import login

# colab secret
HF_TOKEN = userdata.get("HF_TOKEN")

if HF_TOKEN:
    login(token=HF_TOKEN)
    print("Successfully logged in to Hugging Face Hub.")
else:
    print("HF_TOKEN not found in Colab secrets. Add it if the model requires authentication.")

# routing model
MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"

# gpu if available
device = "cuda" if torch.cuda.is_available() else "cpu"

print("Using device:", device)

# 4-bit loading
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

# tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    quantization_config=bnb_config,
    device_map="auto",
)

# inference mode
model.eval()

print("Model loaded:", MODEL_ID)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 10.4 MB/s eta 0:00:00
# Successfully logged in to Hugging Face Hub.
# Using device: cuda
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded: Qwen/Qwen2.5-7B-Instruct

# %%
# generation helper

def generate_text_with_model(
    prompt: str,
    max_new_tokens: int = 80,
) -> str:
    """
    Generate text from a completed prompt.
    Used only for prompt-based routing classifiers.
    """

    # chat-style input
    messages = [
        {
            "role": "user",
            "content": prompt,
        }
    ]

    # qwen chat template
    try:
        formatted_prompt = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
        )
    except Exception:
        formatted_prompt = prompt

    # tokenized input
    inputs = tokenizer(
        formatted_prompt,
        return_tensors="pt",
        truncation=True,
        max_length=4096,
    ).to(device)

    input_length = inputs["input_ids"].shape[-1]

    # no gradients
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
        )

    # new tokens only
    generated_ids = output_ids[0][input_length:]
    answer = tokenizer.decode(generated_ids, skip_special_tokens=True).strip()

    return answer


def parse_json_from_text(raw_output: str) -> dict:
    """
    Try to parse a JSON object from model output.
    If the model returns extra text, extract the first JSON-like block.
    """

    # direct json first
    try:
        return json.loads(raw_output)
    except Exception:
        pass

    # extract json block
    try:
        start_index = raw_output.find("{")
        end_index = raw_output.rfind("}") + 1

        if start_index != -1 and end_index != -1:
            json_text = raw_output[start_index:end_index]
            return json.loads(json_text)
    except Exception:
        pass

    # safe empty fallback
    return {}

# %%
# language detection methods

def detect_language_lingua(user_question: str) -> str:
    """
    Detect whether the user question is English or Dutch using Lingua.

    Returns:
    - 'en'
    - 'nl'
    """

    # fast detector
    detected_language = lingua_detector.detect_language_of(user_question)

    if detected_language == Language.DUTCH:
        return "nl"

    if detected_language == Language.ENGLISH:
        return "en"

    # safe fallback
    return "en"


def detect_language_prompt_based(user_question: str) -> str:
    """
    Detect whether the user question is English or Dutch using the loaded model.

    Returns:
    - 'en'
    - 'nl'
    """

    # classifier prompt
    language_prompt = f"""
You are a language detection classifier for a bilingual household energy chatbot.

Classify the user question as exactly one of these language labels:

1. en
The question is written mainly in English.

2. nl
The question is written mainly in Dutch.

User question:
{user_question}

Return only valid JSON with this exact structure:
{{
  "language": "en",
  "reason": "Brief reason."
}}
""".strip()

    # model prediction
    raw_output = generate_text_with_model(
        prompt=language_prompt,
        max_new_tokens=80,
    )

    # parse label
    parsed_output = parse_json_from_text(raw_output)

    detected_language = parsed_output.get("language", "").strip().lower()

    if detected_language in ["en", "nl"]:
        return detected_language

    # lingua fallback
    return detect_language_lingua(user_question)


def detect_language(
    user_question: str,
    method: str = "lingua",
) -> str:
    """
    Unified language detector.

    Supported methods:
    - 'lingua'
    - 'prompt_based'
    """

    # method switch
    if method == "lingua":
        return detect_language_lingua(user_question)

    if method == "prompt_based":
        return detect_language_prompt_based(user_question)

    raise ValueError("Supported language detection methods are: 'lingua' and 'prompt_based'.")

# %%
# scope detection methods

def contains_keyword(text: str, keywords: list[str]) -> bool:
    """
    Check whether text contains a keyword as a full word or phrase.
    This prevents accidental matches such as 'graph' inside 'paragraph'.
    """

    # case-insensitive match
    text_lower = text.lower()

    # avoid partial words
    for keyword in keywords:
        keyword_lower = keyword.lower()

        if " " in keyword_lower or "-" in keyword_lower:
            if keyword_lower in text_lower:
                return True
        else:
            pattern = r"\b" + re.escape(keyword_lower) + r"\b"
            if re.search(pattern, text_lower):
                return True

    return False


def detect_scope_simple(user_question: str) -> str:
    """
    Rule-based scope detector.

    Returns:
    - 'in_scope'
    - 'out_of_scope'
    """

    # normalized question
    question_lower = user_question.lower()

    # domain terms
    energy_keywords = [
        # English
        "electricity", "energy", "usage", "consumption", "solar", "grid",
        "export", "heat pump", "ventilation", "water use", "water usage",
        "anomaly", "detected", "production", "inverter", "meter", "reading",
        "graph", "energy graph", "usage graph", "consumption graph",
        "peak", "peaks", "device", "appliance", "power", "kwh",

        # Dutch
        "elektriciteit", "elektriciteitsverbruik", "energie", "energieverbruik",
        "zonne", "zonnepanelen", "zonneproductie", "teruglevering",
        "warmtepomp", "ventilatie", "waterverbruik", "afwijking",
        "gedetecteerd", "omvormer", "meter", "grafiek", "energiegrafiek",
        "energiepatroon", "energiepatronen", "piek", "pieken",
        "elektriciteitspiek", "elektriciteitspieken",
        "verbruikspiek", "verbruikspieken",
        "apparaat", "verbruik", "stroom", "kwh", "grafiekje",
    ]

    # exclusion terms
    out_of_scope_keywords = [
        # English
        "recipe", "cook", "stock", "invest", "vote", "election", "trip",
        "travel", "python", "code", "debug", "movie", "translate",
        "wi-fi", "wifi", "router", "joke", "headache", "medical",
        "doctor", "medicine", "spanish",

        # Dutch
        "recept", "koken", "aandeel", "beleggen", "stemmen", "verkiezingen",
        "trip", "reis", "python", "code", "debug", "film", "vertalen",
        "spaans", "wifi", "router", "grap", "hoofdpijn", "medisch",
        "dokter", "medicijn",
    ]

    # keyword flags
    has_energy_keyword = contains_keyword(question_lower, energy_keywords)
    has_out_of_scope_keyword = contains_keyword(question_lower, out_of_scope_keywords)

    if has_out_of_scope_keyword and not has_energy_keyword:
        return "out_of_scope"

    if has_energy_keyword and not has_out_of_scope_keyword:
        return "in_scope"

    # conservative conflict
    if has_out_of_scope_keyword and has_energy_keyword:
        return "out_of_scope"

    # unknown fallback
    return "out_of_scope"


def detect_scope_prompt_based(user_question: str) -> str:
    """
    Detect whether a user question is in scope using the loaded model.

    Returns:
    - 'in_scope'
    - 'out_of_scope'
    """

    # classifier prompt
    scope_prompt = f"""
You are a routing classifier for a BeNext household energy monitoring chatbot.

Classify the user question as one of these labels:

1. in_scope
The question is about household energy monitoring, electricity use, energy consumption, solar production, grid export, heat pumps, ventilation, water use, device-related energy behaviour, energy graphs, peaks, anomalies, or follow-up recommendations based on system readings.

2. out_of_scope
The question is about anything else, such as recipes, stocks, medical advice, politics, travel, coding, movies, translation, jokes, Wi-Fi/router support, or general knowledge.

User question:
{user_question}

Return only valid JSON with this exact structure:
{{
  "scope": "in_scope",
  "reason": "Brief reason."
}}
""".strip()

    # model prediction
    raw_output = generate_text_with_model(
        prompt=scope_prompt,
        max_new_tokens=80,
    )

    # parse label
    parsed_output = parse_json_from_text(raw_output)

    scope = parsed_output.get("scope", "").strip()

    if scope in ["in_scope", "out_of_scope"]:
        return scope

    # rule fallback
    return detect_scope_simple(user_question)


def detect_scope(
    user_question: str,
    method: str = "rule_based",
) -> str:
    """
    Unified scope detector.

    Supported methods:
    - 'rule_based'
    - 'prompt_based'
    """

    # method switch
    if method == "rule_based":
        return detect_scope_simple(user_question)

    if method == "prompt_based":
        return detect_scope_prompt_based(user_question)

    raise ValueError("Supported scope detection methods are: 'rule_based' and 'prompt_based'.")

# %%
# routing evaluation helpers

def get_true_scope(dataset_name: str) -> str:
    """
    Convert dataset name into expected scope label.
    """

    # expected label
    if dataset_name == "out_of_scope":
        return "out_of_scope"

    if dataset_name == "in_scope":
        return "in_scope"

    return "in_scope"

def summarize_detection_results(
    results_df: pd.DataFrame,
    method_column: str,
    correct_column: str,
) -> pd.DataFrame:
    """
    Summarize detection results by method.
    """

    # method summary
    summary_df = (
        results_df
        .groupby(method_column)
        .agg(
            n_items=("item_id", "count"),
            accuracy=(correct_column, "mean"),
            avg_latency_seconds=("latency_seconds", "mean"),
            n_errors=("error_message", lambda x: (x != "").sum()),
        )
        .reset_index()
    )

    return summary_df

# %%
# evaluate language detection

def evaluate_language_detection_on_dataframe(
    input_df: pd.DataFrame,
    language_detection_methods: list[str],
) -> pd.DataFrame:
    """
    Evaluate language detection on the full dataframe.

    True label:
    - input_df["language"]

    Predicted label:
    - detect_language(question, method)
    """

    rows = []

    # progress counter
    total_items = len(input_df)

    # method loop
    for method in language_detection_methods:
        print("=" * 80)
        print(f"Evaluating language detection method: {method}")
        print("=" * 80)

        # item loop
        for row_number, (_, row) in enumerate(input_df.iterrows(), start=1):
            item_id = row.get("item_id", f"row_{row_number}")
            question = row.get("question", "")
            true_language = row.get("language", "")

            print(f"Language detection {row_number}/{total_items}: {item_id} ({method})")

            # item timing
            start_time = time.perf_counter()

            try:
                predicted_language = detect_language(
                    user_question=question,
                    method=method,
                )
                error_message = ""
            except Exception as error:
                # keep failure row
                predicted_language = ""
                error_message = str(error)

            end_time = time.perf_counter()

            # store result
            rows.append({
                "item_id": item_id,
                "base_case_id": row.get("base_case_id", ""),
                "dataset": row.get("dataset", ""),
                "category": row.get("category", ""),
                "question": question,

                "true_language": true_language,
                "predicted_language": predicted_language,
                "language_detection_method": method,
                "language_detection_correct": predicted_language == true_language,

                "latency_seconds": end_time - start_time,
                "error_message": error_message,
            })

    results_df = pd.DataFrame(rows)

    print("\nLanguage detection evaluation finished.")
    print("Results shape:", results_df.shape)

    return results_df


language_detection_results = evaluate_language_detection_on_dataframe(
    input_df=test_df,
    language_detection_methods=["lingua", "prompt_based"],
)

language_detection_summary = summarize_detection_results(
    results_df=language_detection_results,
    method_column="language_detection_method",
    correct_column="language_detection_correct",
)

display(language_detection_summary)

# wrong cases only
display(
    language_detection_results[
        language_detection_results["language_detection_correct"] == False
    ][
        [
            "item_id",
            "dataset",
            "category",
            "question",
            "true_language",
            "predicted_language",
            "language_detection_method",
            "latency_seconds",
            "error_message",
        ]
    ]
)
# Out:
# ================================================================================
# Evaluating language detection method: lingua
# ================================================================================
# Language detection 1/160: OOS_001_EN (lingua)
# Language detection 2/160: OOS_001_NL (lingua)
# Language detection 3/160: OOS_002_EN (lingua)
# Language detection 4/160: OOS_002_NL (lingua)
# Language detection 5/160: OOS_003_EN (lingua)
# Language detection 6/160: OOS_003_NL (lingua)
# Language detection 7/160: OOS_004_EN (lingua)
# Language detection 8/160: OOS_004_NL (lingua)
# Language detection 9/160: OOS_005_EN (lingua)
# Language detection 10/160: OOS_005_NL (lingua)
# Language detection 11/160: OOS_006_EN (lingua)
# Language detection 12/160: OOS_006_NL (lingua)
# Language detection 13/160: OOS_007_EN (lingua)
# Language detection 158/160: NEW_033_NL (prompt_based)
# Language detection 159/160: NEW_034_EN (prompt_based)
# Language detection 160/160: NEW_034_NL (prompt_based)
#
# Language detection evaluation finished.
# Results shape: (320, 11)
#   language_detection_method  n_items  accuracy  avg_latency_seconds  n_errors
# 0                    lingua      160       1.0             0.000268         0
# 1              prompt_based      160       1.0             2.880936         0
# Empty DataFrame
# Columns: [item_id, dataset, category, question, true_language, predicted_language, language_detection_method, latency_seconds, error_message]
# Index: []

# %%
# evaluate scope detection

def evaluate_scope_detection_on_dataframe(
    input_df: pd.DataFrame,
    scope_detection_methods: list[str],
) -> pd.DataFrame:
    """
    Evaluate scope detection on the full dataframe.

    True label:
    - baseline -> in_scope
    - out_of_scope -> out_of_scope

    Predicted label:
    - detect_scope(question, method)
    """

    rows = []

    # progress counter
    total_items = len(input_df)

    # method loop
    for method in scope_detection_methods:
        print("=" * 80)
        print(f"Evaluating scope detection method: {method}")
        print("=" * 80)

        # item loop
        for row_number, (_, row) in enumerate(input_df.iterrows(), start=1):
            item_id = row.get("item_id", f"row_{row_number}")
            question = row.get("question", "")
            dataset_name = row.get("dataset", "")
            # benchmark label
            true_scope = get_true_scope(dataset_name)

            print(f"Scope detection {row_number}/{total_items}: {item_id} ({method})")

            # item timing
            start_time = time.perf_counter()

            try:
                predicted_scope = detect_scope(
                    user_question=question,
                    method=method,
                )
                error_message = ""
            except Exception as error:
                # keep failure row
                predicted_scope = ""
                error_message = str(error)

            end_time = time.perf_counter()

            # store result
            rows.append({
                "item_id": item_id,
                "base_case_id": row.get("base_case_id", ""),
                "dataset": dataset_name,
                "category": row.get("category", ""),
                "question": question,

                "true_scope": true_scope,
                "predicted_scope": predicted_scope,
                "scope_detection_method": method,
                "scope_detection_correct": predicted_scope == true_scope,

                "latency_seconds": end_time - start_time,
                "error_message": error_message,
            })

    results_df = pd.DataFrame(rows)

    print("\nScope detection evaluation finished.")
    print("Results shape:", results_df.shape)

    return results_df


scope_detection_results = evaluate_scope_detection_on_dataframe(
    input_df=test_df,
    scope_detection_methods=["rule_based", "prompt_based"],
)

scope_detection_summary = summarize_detection_results(
    results_df=scope_detection_results,
    method_column="scope_detection_method",
    correct_column="scope_detection_correct",
)

display(scope_detection_summary)

# wrong cases only
display(
    scope_detection_results[
        scope_detection_results["scope_detection_correct"] == False
    ][
        [
            "item_id",
            "dataset",
            "category",
            "question",
            "true_scope",
            "predicted_scope",
            "scope_detection_method",
            "latency_seconds",
            "error_message",
        ]
    ]
)
# Out:
# ================================================================================
# Evaluating scope detection method: rule_based
# ================================================================================
# Scope detection 1/160: OOS_001_EN (rule_based)
# Scope detection 2/160: OOS_001_NL (rule_based)
# Scope detection 3/160: OOS_002_EN (rule_based)
# Scope detection 4/160: OOS_002_NL (rule_based)
# Scope detection 5/160: OOS_003_EN (rule_based)
# Scope detection 6/160: OOS_003_NL (rule_based)
# Scope detection 7/160: OOS_004_EN (rule_based)
# Scope detection 8/160: OOS_004_NL (rule_based)
# Scope detection 9/160: OOS_005_EN (rule_based)
# Scope detection 10/160: OOS_005_NL (rule_based)
# Scope detection 11/160: OOS_006_EN (rule_based)
# Scope detection 12/160: OOS_006_NL (rule_based)
# Scope detection 13/160: OOS_007_EN (rule_based)
# Scope detection 14/160: OOS_007_NL (rule_based)
# Scope detection 15/160: OOS_008_EN (rule_based)
# Scope detection 16/160: OOS_008_NL (rule_based)
# Scope detection 17/160: OOS_009_EN (rule_based)
# Scope detection 18/160: OOS_009_NL (rule_based)
# Scope detection 19/160: OOS_010_EN (rule_based)
# Scope detection 20/160: OOS_010_NL (rule_based)
# Scope detection 21/160: OOS_011_EN (rule_based)
# Scope detection 22/160: OOS_011_NL (rule_based)
# Scope detection 23/160: OOS_012_EN (rule_based)
# Scope detection 24/160: OOS_012_NL (rule_based)
# Scope detection 25/160: OOS_013_EN (rule_based)
# Scope detection 26/160: OOS_013_NL (rule_based)
# Scope detection 27/160: OOS_014_EN (rule_based)
# Scope detection 28/160: OOS_014_NL (rule_based)
# Scope detection 29/160: OOS_015_EN (rule_based)
# Scope detection 30/160: OOS_015_NL (rule_based)
# Scope detection 31/160: OOS_016_EN (rule_based)
# Scope detection 32/160: OOS_016_NL (rule_based)
# Scope detection 33/160: OOS_017_EN (rule_based)
# Scope detection 34/160: OOS_017_NL (rule_based)
# Scope detection 35/160: OOS_018_EN (rule_based)
# Scope detection 36/160: OOS_018_NL (rule_based)
# Scope detection 37/160: OOS_019_EN (rule_based)
# Scope detection 38/160: OOS_019_NL (rule_based)
# Scope detection 39/160: OOS_020_EN (rule_based)
# Scope detection 40/160: OOS_020_NL (rule_based)
# Scope detection 41/160: OOS_021_EN (rule_based)
# Scope detection 42/160: OOS_021_NL (rule_based)
# Scope detection 43/160: OOS_022_EN (rule_based)
# Scope detection 44/160: OOS_022_NL (rule_based)
# Scope detection 45/160: OOS_023_EN (rule_based)
# Scope detection 46/160: OOS_023_NL (rule_based)
# Scope detection 47/160: OOS_024_EN (rule_based)
# Scope detection 48/160: OOS_024_NL (rule_based)
# Scope detection 49/160: OOS_025_EN (rule_based)
# Scope detection 50/160: OOS_025_NL (rule_based)
# Scope detection 51/160: OOS_026_EN (rule_based)
# Scope detection 52/160: OOS_026_NL (rule_based)
# Scope detection 53/160: OOS_027_EN (rule_based)
# Scope detection 54/160: OOS_027_NL (rule_based)
# Scope detection 55/160: OOS_028_EN (rule_based)
# Scope detection 56/160: OOS_028_NL (rule_based)
# Scope detection 57/160: OOS_029_EN (rule_based)
# Scope detection 58/160: OOS_029_NL (rule_based)
# Scope detection 59/160: OOS_030_EN (rule_based)
# Scope detection 60/160: OOS_030_NL (rule_based)
# Scope detection 61/160: EXISTING_001_EN (rule_based)
# Scope detection 62/160: EXISTING_001_NL (rule_based)
# Scope detection 63/160: EXISTING_002_EN (rule_based)
# Scope detection 64/160: EXISTING_002_NL (rule_based)
# Scope detection 65/160: EXISTING_003_EN (rule_based)
# Scope detection 66/160: EXISTING_003_NL (rule_based)
# Scope detection 67/160: EXISTING_004_EN (rule_based)
# Scope detection 68/160: EXISTING_004_NL (rule_based)
# Scope detection 69/160: EXISTING_005_EN (rule_based)
# Scope detection 70/160: EXISTING_005_NL (rule_based)
# Scope detection 71/160: EXISTING_006_EN (rule_based)
# Scope detection 72/160: EXISTING_006_NL (rule_based)
# Scope detection 73/160: EXISTING_007_EN (rule_based)
# Scope detection 74/160: EXISTING_007_NL (rule_based)
# Scope detection 75/160: EXISTING_008_EN (rule_based)
# Scope detection 76/160: EXISTING_008_NL (rule_based)
# Scope detection 77/160: EXISTING_009_EN (rule_based)
# Scope detection 78/160: EXISTING_009_NL (rule_based)
# Scope detection 79/160: EXISTING_010_EN (rule_based)
# Scope detection 80/160: EXISTING_010_NL (rule_based)
# Scope detection 81/160: EXISTING_011_EN (rule_based)
# Scope detection 82/160: EXISTING_011_NL (rule_based)
# Scope detection 83/160: EXISTING_012_EN (rule_based)
# Scope detection 84/160: EXISTING_012_NL (rule_based)
# Scope detection 85/160: EXISTING_013_EN (rule_based)
# Scope detection 86/160: EXISTING_013_NL (rule_based)
# Scope detection 87/160: EXISTING_014_EN (rule_based)
# Scope detection 88/160: EXISTING_014_NL (rule_based)
# Scope detection 89/160: EXISTING_015_EN (rule_based)
# Scope detection 90/160: EXISTING_015_NL (rule_based)
# Scope detection 91/160: EXISTING_016_EN (rule_based)
# Scope detection 92/160: EXISTING_016_NL (rule_based)
# Scope detection 93/160: NEW_001_EN (rule_based)
# Scope detection 94/160: NEW_001_NL (rule_based)
# Scope detection 95/160: NEW_002_EN (rule_based)
# Scope detection 96/160: NEW_002_NL (rule_based)
# Scope detection 97/160: NEW_003_EN (rule_based)
# Scope detection 98/160: NEW_003_NL (rule_based)
# Scope detection 99/160: NEW_004_EN (rule_based)
# Scope detection 100/160: NEW_004_NL (rule_based)
# Scope detection 101/160: NEW_005_EN (rule_based)
# Scope detection 102/160: NEW_005_NL (rule_based)
# Scope detection 103/160: NEW_006_EN (rule_based)
# Scope detection 104/160: NEW_006_NL (rule_based)
# Scope detection 105/160: NEW_007_EN (rule_based)
# Scope detection 106/160: NEW_007_NL (rule_based)
# Scope detection 107/160: NEW_008_EN (rule_based)
# Scope detection 108/160: NEW_008_NL (rule_based)
# Scope detection 109/160: NEW_009_EN (rule_based)
# Scope detection 110/160: NEW_009_NL (rule_based)
# Scope detection 111/160: NEW_010_EN (rule_based)
# Scope detection 112/160: NEW_010_NL (rule_based)
# Scope detection 113/160: NEW_011_EN (rule_based)
# Scope detection 114/160: NEW_011_NL (rule_based)
# Scope detection 115/160: NEW_012_EN (rule_based)
# Scope detection 116/160: NEW_012_NL (rule_based)
# Scope detection 117/160: NEW_013_EN (rule_based)
# Scope detection 118/160: NEW_013_NL (rule_based)
# Scope detection 119/160: NEW_014_EN (rule_based)
# Scope detection 120/160: NEW_014_NL (rule_based)
# Scope detection 121/160: NEW_015_EN (rule_based)
# Scope detection 122/160: NEW_015_NL (rule_based)
# Scope detection 123/160: NEW_016_EN (rule_based)
# Scope detection 124/160: NEW_016_NL (rule_based)
# Scope detection 125/160: NEW_017_EN (rule_based)
# Scope detection 126/160: NEW_017_NL (rule_based)
# Scope detection 127/160: NEW_018_EN (rule_based)
# Scope detection 128/160: NEW_018_NL (rule_based)
# Scope detection 129/160: NEW_019_EN (rule_based)
# Scope detection 130/160: NEW_019_NL (rule_based)
# Scope detection 131/160: NEW_020_EN (rule_based)
# Scope detection 132/160: NEW_020_NL (rule_based)
# Scope detection 133/160: NEW_021_EN (rule_based)
# Scope detection 134/160: NEW_021_NL (rule_based)
# Scope detection 135/160: NEW_022_EN (rule_based)
# Scope detection 136/160: NEW_022_NL (rule_based)
# Scope detection 137/160: NEW_023_EN (rule_based)
# Scope detection 138/160: NEW_023_NL (rule_based)
# Scope detection 139/160: NEW_024_EN (rule_based)
# Scope detection 140/160: NEW_024_NL (rule_based)
# Scope detection 141/160: NEW_025_EN (rule_based)
# Scope detection 142/160: NEW_025_NL (rule_based)
# Scope detection 143/160: NEW_026_EN (rule_based)
# Scope detection 144/160: NEW_026_NL (rule_based)
# Scope detection 145/160: NEW_027_EN (rule_based)
# Scope detection 146/160: NEW_027_NL (rule_based)
# Scope detection 147/160: NEW_028_EN (rule_based)
# Scope detection 148/160: NEW_028_NL (rule_based)
# Scope detection 149/160: NEW_029_EN (rule_based)
# Scope detection 150/160: NEW_029_NL (rule_based)
# Scope detection 151/160: NEW_030_EN (rule_based)
# Scope detection 152/160: NEW_030_NL (rule_based)
# Scope detection 153/160: NEW_031_EN (rule_based)
# Scope detection 154/160: NEW_031_NL (rule_based)
# Scope detection 155/160: NEW_032_EN (rule_based)
# Scope detection 156/160: NEW_032_NL (rule_based)
# Scope detection 157/160: NEW_033_EN (rule_based)
# Scope detection 158/160: NEW_033_NL (rule_based)
# Scope detection 159/160: NEW_034_EN (rule_based)
# Scope detection 160/160: NEW_034_NL (rule_based)
# ================================================================================
# Evaluating scope detection method: prompt_based
# ================================================================================
# Scope detection 1/160: OOS_001_EN (prompt_based)
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Scope detection 2/160: OOS_001_NL (prompt_based)
# Scope detection 3/160: OOS_002_EN (prompt_based)
# Scope detection 4/160: OOS_002_NL (prompt_based)
# Scope detection 5/160: OOS_003_EN (prompt_based)
# Scope detection 6/160: OOS_003_NL (prompt_based)
# Scope detection 7/160: OOS_004_EN (prompt_based)
# Scope detection 8/160: OOS_004_NL (prompt_based)
# Scope detection 9/160: OOS_005_EN (prompt_based)
# Scope detection 10/160: OOS_005_NL (prompt_based)
# Scope detection 11/160: OOS_006_EN (prompt_based)
# Scope detection 12/160: OOS_006_NL (prompt_based)
# Scope detection 13/160: OOS_007_EN (prompt_based)
# Scope detection 14/160: OOS_007_NL (prompt_based)
# Scope detection 15/160: OOS_008_EN (prompt_based)
# Scope detection 16/160: OOS_008_NL (prompt_based)
# Scope detection 17/160: OOS_009_EN (prompt_based)
# Scope detection 18/160: OOS_009_NL (prompt_based)
# Scope detection 19/160: OOS_010_EN (prompt_based)
# Scope detection 20/160: OOS_010_NL (prompt_based)
# Scope detection 21/160: OOS_011_EN (prompt_based)
# Scope detection 22/160: OOS_011_NL (prompt_based)
# Scope detection 23/160: OOS_012_EN (prompt_based)
# Scope detection 24/160: OOS_012_NL (prompt_based)
# Scope detection 25/160: OOS_013_EN (prompt_based)
# Scope detection 26/160: OOS_013_NL (prompt_based)
# Scope detection 27/160: OOS_014_EN (prompt_based)
# Scope detection 28/160: OOS_014_NL (prompt_based)
# Scope detection 29/160: OOS_015_EN (prompt_based)
# Scope detection 30/160: OOS_015_NL (prompt_based)
# Scope detection 31/160: OOS_016_EN (prompt_based)
# Scope detection 32/160: OOS_016_NL (prompt_based)
# Scope detection 33/160: OOS_017_EN (prompt_based)
# Scope detection 34/160: OOS_017_NL (prompt_based)
# Scope detection 35/160: OOS_018_EN (prompt_based)
# Scope detection 36/160: OOS_018_NL (prompt_based)
# Scope detection 37/160: OOS_019_EN (prompt_based)
# Scope detection 38/160: OOS_019_NL (prompt_based)
# Scope detection 39/160: OOS_020_EN (prompt_based)
# Scope detection 40/160: OOS_020_NL (prompt_based)
# Scope detection 41/160: OOS_021_EN (prompt_based)
# Scope detection 42/160: OOS_021_NL (prompt_based)
# Scope detection 43/160: OOS_022_EN (prompt_based)
# Scope detection 44/160: OOS_022_NL (prompt_based)
# Scope detection 45/160: OOS_023_EN (prompt_based)
# Scope detection 46/160: OOS_023_NL (prompt_based)
# Scope detection 47/160: OOS_024_EN (prompt_based)
# Scope detection 48/160: OOS_024_NL (prompt_based)
# Scope detection 49/160: OOS_025_EN (prompt_based)
# Scope detection 50/160: OOS_025_NL (prompt_based)
# Scope detection 51/160: OOS_026_EN (prompt_based)
# Scope detection 52/160: OOS_026_NL (prompt_based)
# Scope detection 53/160: OOS_027_EN (prompt_based)
# Scope detection 54/160: OOS_027_NL (prompt_based)
# Scope detection 55/160: OOS_028_EN (prompt_based)
# Scope detection 56/160: OOS_028_NL (prompt_based)
# Scope detection 57/160: OOS_029_EN (prompt_based)
# Scope detection 58/160: OOS_029_NL (prompt_based)
# Scope detection 59/160: OOS_030_EN (prompt_based)
# Scope detection 60/160: OOS_030_NL (prompt_based)
# Scope detection 61/160: EXISTING_001_EN (prompt_based)
# Scope detection 62/160: EXISTING_001_NL (prompt_based)
# Scope detection 63/160: EXISTING_002_EN (prompt_based)
# Scope detection 64/160: EXISTING_002_NL (prompt_based)
# Scope detection 65/160: EXISTING_003_EN (prompt_based)
# Scope detection 66/160: EXISTING_003_NL (prompt_based)
# Scope detection 67/160: EXISTING_004_EN (prompt_based)
# Scope detection 68/160: EXISTING_004_NL (prompt_based)
# Scope detection 69/160: EXISTING_005_EN (prompt_based)
# Scope detection 70/160: EXISTING_005_NL (prompt_based)
# Scope detection 71/160: EXISTING_006_EN (prompt_based)
# Scope detection 72/160: EXISTING_006_NL (prompt_based)
# Scope detection 73/160: EXISTING_007_EN (prompt_based)
# Scope detection 74/160: EXISTING_007_NL (prompt_based)
# Scope detection 75/160: EXISTING_008_EN (prompt_based)
# Scope detection 76/160: EXISTING_008_NL (prompt_based)
# Scope detection 77/160: EXISTING_009_EN (prompt_based)
# Scope detection 78/160: EXISTING_009_NL (prompt_based)
# Scope detection 79/160: EXISTING_010_EN (prompt_based)
# Scope detection 80/160: EXISTING_010_NL (prompt_based)
# Scope detection 81/160: EXISTING_011_EN (prompt_based)
# Scope detection 82/160: EXISTING_011_NL (prompt_based)
# Scope detection 83/160: EXISTING_012_EN (prompt_based)
# Scope detection 84/160: EXISTING_012_NL (prompt_based)
# Scope detection 85/160: EXISTING_013_EN (prompt_based)
# Scope detection 86/160: EXISTING_013_NL (prompt_based)
# Scope detection 87/160: EXISTING_014_EN (prompt_based)
# Scope detection 88/160: EXISTING_014_NL (prompt_based)
# Scope detection 89/160: EXISTING_015_EN (prompt_based)
# Scope detection 90/160: EXISTING_015_NL (prompt_based)
# Scope detection 91/160: EXISTING_016_EN (prompt_based)
# Scope detection 92/160: EXISTING_016_NL (prompt_based)
# Scope detection 93/160: NEW_001_EN (prompt_based)
# Scope detection 94/160: NEW_001_NL (prompt_based)
# Scope detection 95/160: NEW_002_EN (prompt_based)
# Scope detection 96/160: NEW_002_NL (prompt_based)
# Scope detection 97/160: NEW_003_EN (prompt_based)
# Scope detection 98/160: NEW_003_NL (prompt_based)
# Scope detection 99/160: NEW_004_EN (prompt_based)
# Scope detection 100/160: NEW_004_NL (prompt_based)
# Scope detection 101/160: NEW_005_EN (prompt_based)
# Scope detection 102/160: NEW_005_NL (prompt_based)
# Scope detection 103/160: NEW_006_EN (prompt_based)
# Scope detection 104/160: NEW_006_NL (prompt_based)
# Scope detection 105/160: NEW_007_EN (prompt_based)
# Scope detection 106/160: NEW_007_NL (prompt_based)
# Scope detection 107/160: NEW_008_EN (prompt_based)
# Scope detection 108/160: NEW_008_NL (prompt_based)
# Scope detection 109/160: NEW_009_EN (prompt_based)
# Scope detection 110/160: NEW_009_NL (prompt_based)
# Scope detection 111/160: NEW_010_EN (prompt_based)
# Scope detection 112/160: NEW_010_NL (prompt_based)
# Scope detection 113/160: NEW_011_EN (prompt_based)
# Scope detection 114/160: NEW_011_NL (prompt_based)
# Scope detection 115/160: NEW_012_EN (prompt_based)
# Scope detection 116/160: NEW_012_NL (prompt_based)
# Scope detection 117/160: NEW_013_EN (prompt_based)
# Scope detection 118/160: NEW_013_NL (prompt_based)
# Scope detection 119/160: NEW_014_EN (prompt_based)
# Scope detection 120/160: NEW_014_NL (prompt_based)
# Scope detection 121/160: NEW_015_EN (prompt_based)
# Scope detection 122/160: NEW_015_NL (prompt_based)
# Scope detection 123/160: NEW_016_EN (prompt_based)
# Scope detection 124/160: NEW_016_NL (prompt_based)
# Scope detection 125/160: NEW_017_EN (prompt_based)
# Scope detection 126/160: NEW_017_NL (prompt_based)
# Scope detection 127/160: NEW_018_EN (prompt_based)
# Scope detection 128/160: NEW_018_NL (prompt_based)
# Scope detection 129/160: NEW_019_EN (prompt_based)
# Scope detection 130/160: NEW_019_NL (prompt_based)
# Scope detection 131/160: NEW_020_EN (prompt_based)
# Scope detection 132/160: NEW_020_NL (prompt_based)
# Scope detection 133/160: NEW_021_EN (prompt_based)
# Scope detection 134/160: NEW_021_NL (prompt_based)
# Scope detection 135/160: NEW_022_EN (prompt_based)
# Scope detection 136/160: NEW_022_NL (prompt_based)
# Scope detection 137/160: NEW_023_EN (prompt_based)
# Scope detection 138/160: NEW_023_NL (prompt_based)
# Scope detection 139/160: NEW_024_EN (prompt_based)
# Scope detection 140/160: NEW_024_NL (prompt_based)
# Scope detection 141/160: NEW_025_EN (prompt_based)
# Scope detection 142/160: NEW_025_NL (prompt_based)
# Scope detection 143/160: NEW_026_EN (prompt_based)
# Scope detection 144/160: NEW_026_NL (prompt_based)
# Scope detection 145/160: NEW_027_EN (prompt_based)
# Scope detection 146/160: NEW_027_NL (prompt_based)
# Scope detection 147/160: NEW_028_EN (prompt_based)
# Scope detection 148/160: NEW_028_NL (prompt_based)
# Scope detection 149/160: NEW_029_EN (prompt_based)
# Scope detection 150/160: NEW_029_NL (prompt_based)
# Scope detection 151/160: NEW_030_EN (prompt_based)
# Scope detection 152/160: NEW_030_NL (prompt_based)
# Scope detection 153/160: NEW_031_EN (prompt_based)
# Scope detection 154/160: NEW_031_NL (prompt_based)
# Scope detection 155/160: NEW_032_EN (prompt_based)
# Scope detection 156/160: NEW_032_NL (prompt_based)
# Scope detection 157/160: NEW_033_EN (prompt_based)
# Scope detection 158/160: NEW_033_NL (prompt_based)
# Scope detection 159/160: NEW_034_EN (prompt_based)
# Scope detection 160/160: NEW_034_NL (prompt_based)
#
# Scope detection evaluation finished.
# Results shape: (320, 11)
#   scope_detection_method  n_items  accuracy  avg_latency_seconds  n_errors
# 0           prompt_based      160   0.90000             3.366967         0
# 1             rule_based      160   0.69375             0.000237         0
#              item_id       dataset category  \
# 4         OOS_003_EN  out_of_scope
# 5         OOS_003_NL  out_of_scope
# 8         OOS_005_EN  out_of_scope
# 16        OOS_009_EN  out_of_scope
# 17        OOS_009_NL  out_of_scope
# ..               ...           ...      ...
# 209       OOS_025_NL  out_of_scope
# 215       OOS_028_NL  out_of_scope
# 246  EXISTING_014_EN       library
# 293       NEW_021_NL       library
# 299       NEW_024_NL       library
#
#                                               question    true_scope  \
# 4    I have chest pain when the ventilation is on. ...  out_of_scope
# 5    Ik krijg pijn op de borst als de ventilatie aa...  out_of_scope
# 8    Which political party has the best energy policy?  out_of_scope
# 16   Can I legally refuse to pay EPV because my sol...  out_of_scope
# 17   Mag ik juridisch weigeren EPV te betalen omdat...  out_of_scope
# ..                                                 ...           ...
# 209  Moet ik nieuwe zonnepanelen kopen omdat mijn o...  out_of_scope
# 215  Kun je de EPV-bundeldrempel in mijn app aanpas...  out_of_scope
# 246  The net-metering scheme is being phased out. H...      in_scope
# 293  De app is sinds gisteren niet bijgewerkt. Kan ...      in_scope
# 299  Wat betekent 'gebouwgebonden energieverbruik' ...      in_scope
#
#     predicted_scope scope_detection_method  latency_seconds error_message
# 4          in_scope             rule_based         0.000367
# 5          in_scope             rule_based         0.000290
# 8          in_scope             rule_based         0.000110
# 16         in_scope             rule_based         0.000232
# 17         in_scope             rule_based         0.000350
# ..              ...                    ...              ...           ...
# 209        in_scope           prompt_based         2.855409
# 215        in_scope           prompt_based         3.673842
# 246    out_of_scope           prompt_based         3.793375
# 293    out_of_scope           prompt_based         2.863382
# 299    out_of_scope           prompt_based         3.942418
#
# [65 rows x 9 columns]
